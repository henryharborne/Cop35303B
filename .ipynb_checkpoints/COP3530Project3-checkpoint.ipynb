# %% [markdown]
# # COP3530 Project 3 - Spotifython
# ## Constantinos Barmpouris, Henry Harborne, Austin Spangler

# %% [markdown]
# # References

# %% [markdown]
# ### We would like to credit the following courses for providing us with inspiration and knowledge necessary for the ideas and implementation of our algorithms.
# ### EEL4930 - Applied Machine Learning Systems (taken by Constantinos Barmpouris)
# - Distance metrics
# - Data preprocessing
# - Data exploratory analysis
# ### CIS4930 - Intro to Machine Learning (taken by Henry Harborne)
# - Algorithm implementation
# - Data preprocessing
# - Data exploratory analysis
# ### QMB3302 - Foundations of Business Analytics & AI (taken by Constantinos Barmpouris and Austin Spangler)
# - Output structure
# - Data exploratory analysis
# - Distance metrics
# ### STA4273 - Statistical Computing in R (taken by Constantinos Barmpouris)
# - Algorithm statistical theory

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("dataset.csv")

# %% [markdown]
# # Data Exploratory Analysis

# %%
data.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
# Tells us number of songs in dataset.
data.shape
# Out:
# (114000, 21)

# %%
# Seeing columns let us determine which features we will/won't need for training models.
data.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
data['track_name'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                             Comedy
# 1                   Ghost - Acoustic
# 2                     To Begin Again
# 3         Can't Help Falling In Love
# 4                            Hold On
#                      ...
# 113995           Sleep My Little Boy
# 113996              Water Into Light
# 113997                Miss Perfumado
# 113998                       Friends
# 113999                     Barbincor
# Name: track_name, Length: 114000, dtype: object>

# %%
np.unique(data['track_genre'])
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
#        'new-age', 'opera', 'pagode', 'party', 'piano', 'pop', 'pop-film',
#        'power-pop', 'progressive-house', 'psych-rock', 'punk',
#        'punk-rock', 'r-n-b', 'reggae', 'reggaeton', 'rock', 'rock-n-roll',
#        'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo',
#        'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter',
#        'soul', 'spanish', 'study', 'swedish', 'synth-pop', 'tango',
#        'techno', 'trance', 'trip-hop', 'turkish', 'world-music'],
#       dtype=object)

# %% [markdown]
# # Data Preprocessing

# %%
# Drop Unnamed because it doesn't help with model training.
data.drop(['Unnamed: 0'], axis=1, inplace=True)
data_numeric = data.select_dtypes(include=[np.number])

# %%
data_numeric.columns
# Out:
# Index(['popularity', 'duration_ms', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
# Scaling Data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_numeric)

# %% [markdown]
# # KNN

# %%
#KNN with cosine similarity, KNN from scratch was originally taught in CIS4930

def cosineSim(vec1, vec2):
    dotProduct = np.dot(vec1, vec2)
    magnitude = np.linalg.norm(vec1) * np.linalg.norm(vec2)
    if magnitude != 0:
        return (dotProduct / magnitude)
    else:
        return 0
def knnRecommend(userSong, data, k=5):
    userVec = data[userSong]
    similarities = np.array([cosineSim(userVec, data[i]) for i in range(len(data))])
    recommended = np.argsort(-similarities)[1:k+1]
    return recommended

# %% [markdown]
# # Naive Bayes

# %%
# Naive Bayes, Naive Bayes from scratch was originally taught in CIS4930 but tailored to adhere to this projects guidelines.
class NaiveBayes:
    def __init__(self):
        self.classes = None
        self.means = {}
        self.variances = {}
        self.priors = {}

    def fit(self, X, y):
        self.classes = np.unique(y)
        # Can't use class, changed to cls
        for cls in self.classes:
            X_c = X[y == cls]
            self.means[cls] = np.mean(X_c, axis=0)
            self.variances[cls] = np.var(X_c, axis=0)
            self.priors[cls] = X_c.shape[0] / X.shape[0]

    def calcLikelihood(self, cls, x):
        mean = self.means[cls]
        variance = self.variances[cls]
        numerator = np.exp(-((x - mean) ** 2) / (2 * variance))
        denominator = np.sqrt(2 * np.pi * variance)
        return numerator / denominator

    def calcPosterior(self, x):
        posteriors = {}
        for cls in self.classes:
            prior = self.priors[cls]
            likelihood = np.prod(self.calcLikelihood(cls, x))
            posteriors[cls] = prior * likelihood
        return posteriors

    def predict(self, X, song_names, top_n=3):
        predictions = []
        for x in X:
            posteriors = self.calcPosterior(x)
            # Fixed bug with no output
            sorted_classes = sorted(posteriors.items(), key=lambda item: item[1], reverse=True)
            top_predictions = [song_names[cls] for cls, _ in sorted_classes[:top_n]]
            predictions.append(top_predictions)
        return predictions

# %%
# Train NB, kmeans was originally taught in CIS4930, EEL4930
kmeans = KMeans(n_clusters=5, random_state=42)
labels = kmeans.fit_predict(data_scaled)
nb = NaiveBayes()
nb.fit(data_scaled, labels)

# %%
# Function called in Results that generates final recs in output
# Used knowledge from CIS4930, EEL4930 for implementation
def recommendNB(userSongID, X, labels, model, k=5):
    userLabels = model.predict(X[userSongID:userSongID+1], data['track_name'], top_n=3)[0]
    userSongVector = X[userSongID]
    distances = np.linalg.norm(X - userSongVector, axis=1)
    recommendations = np.where(np.isin(data['track_name'].iloc[labels], userLabels))[0]
    sorted_recommendations = recommendations[np.argsort(distances[recommendations])]
    return sorted_recommendations[:k]

# %% [markdown]
# # Results

# %%
##### Previous knowledge from Business Analytics class plays a factor in effectively displaying results in Jupyter Notebooks in a comprehensible way to users.
print("Welcome to the Song Recommendation System!")
print("Search for a song by typing part of its name." 
"The program will output 3 recommendations using KNN, 3 using Naive Bayes,"
"and determine the most closely linked song using Euclidean distance.")

# Prevents errors stemming from precense of null values
userSongs = []
data['track_name'] = data['track_name'].fillna('')
data['artists'] = data['artists'].fillna('')

# Allow the user to search and select a song
while True:
    search_query = input("Enter part of the song name to search: ").strip().lower()
    matching_songs = data[data['track_name'].str.lower().str.contains(search_query, na=False)]
    
    # Removes duplicate songs that aren't registered as duplicates in dataset
    matching_songs = matching_songs.drop_duplicates(subset=['track_name', 'artists'])

    # Have this to prevent error when user enters song not in dataset.
    if matching_songs.empty:
        print("No songs found. Please try again.")
    else:
        print("\nMatching songs:")
        for i, (index, row) in enumerate(matching_songs.iterrows(), 1):
            print(f"{i}: {row['track_name']} by {row['artists']}")
        
        try:
            # Ask the user to pick from the matches
            choice = int(input("\nEnter the number corresponding to your song choice: ")) - 1
            if 0 <= choice < len(matching_songs):
                selected_song = matching_songs.iloc[choice]
                print(f"You selected: {selected_song['track_name']} by {selected_song['artists']}")
                userSongs.append(selected_song.name)  # Store the index of the selected song
                break
            else:
                print("Invalid choice. Please try again.")
        except ValueError:
            print("Please enter a valid number.")

# Found these features to be the best when calculating recommendations
songFeatures = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 
                'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
selectedFeatures = data.loc[userSongs[0], songFeatures].values.reshape(1, -1)

for songIndex in userSongs:
    print(f"\nRecommendations For: '{data.loc[songIndex, 'track_name']}' by {data.loc[songIndex, 'artists']}:")

    # Using KNN
    print("\nUsing KNN:")
    knnRecs = knnRecommend(songIndex, data_scaled, k=10)  # Request more recommendations initially, prevents bug where <3 songs are recommended.
    # Filter out the user's input song and deduplicate KNN recommendations
    knnRecs_df = data.loc[knnRecs, ['track_name', 'artists']].drop_duplicates()
    knnRecs_df = knnRecs_df[
        (knnRecs_df['track_name'] != data.loc[songIndex, 'track_name']) |
        (knnRecs_df['artists'] != data.loc[songIndex, 'artists'])
    ]
    unique_knn_recs = knnRecs_df.index[:3]  # Limit to 3 unique recommendations
    for rec in unique_knn_recs:
        print(f"- {data.loc[rec, 'track_name']} by {data.loc[rec, 'artists']}")

    # Using Naive Bayes
    print("\nUsing Naive Bayes:")
    nbRecs = recommendNB(songIndex, data_scaled, labels, nb, k=10)  # Request more recommendations initially, same bug as KNN fixed
    # Filter out the user's input song and deduplicate Naive Bayes recommendations
    nbRecs_df = data.loc[nbRecs, ['track_name', 'artists']].drop_duplicates()
    nbRecs_df = nbRecs_df[
        (nbRecs_df['track_name'] != data.loc[songIndex, 'track_name']) |
        (nbRecs_df['artists'] != data.loc[songIndex, 'artists'])
    ]
    unique_nb_recs = nbRecs_df.index[:3]  # Limit to 3 unique recommendations
    for rec in unique_nb_recs:
        print(f"- {data.loc[rec, 'track_name']} by {data.loc[rec, 'artists']}")

# Euclidean distance for most closely linked song, in the program this is how we calculate better algorithm but there are many more below.
from sklearn.metrics.pairwise import euclidean_distances

print("\nDetermining the most closely linked song using Euclidean distance:")
allRecommendations = list(unique_knn_recs) + list(unique_nb_recs)
userSongFeatures = data_scaled[userSongs[0]].reshape(1, -1)
distances = euclidean_distances(data_scaled[allRecommendations], userSongFeatures)
#Argmin found and cited from here: https://www.geeksforgeeks.org/numpy-argmin-python/
closestIndex = allRecommendations[distances.argmin()]

print(f"\nThe most closely linked song is: '{data.loc[closestIndex, 'track_name']}' by {data.loc[closestIndex, 'artists']}")
# Out:
# Welcome to the Song Recommendation System!
# Search for a song by typing part of its name.The program will output 3 recommendations using KNN, 3 using Naive Bayes,and determine the most closely linked song using Euclidean distance.
# Enter part of the song name to search:  happy
# Matching songs:
# 1: We Could Still Be Happy by Rachael Yamagata
# 2: Happy by Speedometer
# 3: Happy Beat by Mandrill
# 4: You've Made Me So Very Happy featuring Ria Currie by Speedometer;Ria Currie
# 5: Happy Pills by Weathers
# 6: Happy Holiday / Holiday Season - Medley by Michael W. Smith
# 7: Happy End by Gruzja
# 8: Never Happy Till I'm Full Of Sorrow by Blue Moon Rising
# 9: Happy Place (feat. Jasmine Thompson) by SAINT PHNX;Jasmine Thompson
# 10: Happy by The Rolling Stones
# 11: I'm Happy Just To Dance With You - Remastered 2009 by The Beatles
# 12: I Want to See You Happy by Daniel Pemberton
# 13: Whatever Makes You Happy by Ten City
# 14: Happy (James Priestley & Dan Berkson's Remix) by Robert Owens
# 15: Happy (feat. Kevin Irving) - Original Mix by Bad Boy Bill;Kevin Irving
# 16: Happy Birthday Song by CoComelon
# 17: If You're Happy and You Know It by CoComelon
# 18: If You're Happy and You Know It by The Wiggles
# 19: If You're Happy by Super Simple Songs;Noodle & Pals
# 20: Be Happy With Baby Shark by Pinkfong
# 21: If You're Happy and You Know It - Clap Your Hands by Zouzounia
# 22: Happy Birthday to You by Sing n Play
# 23: If You're Happy and You Know It by Mother Goose Club
# 24: If You're Happy and You Know It by LooLoo Kids
# 25: If You’re Happy and You Know It by Dave and Ava
# 26: Happy and You Know It by Pancake Manor
# 27: Happy Birthday by The Kiboomers
# 28: If You Are Happy and You Know It (Clap Your Hands) by Little Boo & Friends
# 29: Happy Days Are Here Again / Get Happy by Glee Cast
# 30: Die A Happy Man by Thomas Rhett
# 31: Happy Anywhere by Blake Shelton;Gwen Stefani
# 32: Happy Does by Kenny Chesney
# 33: Hiphappy by El Shaaki;Nitro MC;Donexprs;Flor De Rap;Lechero Mon;jimmy Fernadez;Gedos;Crea BeatBox;Sponer;Delaion
# 34: Breathe, Be Happy by Tep No
# 35: Trigger Happy (Safety Off) by Jeff Mills;Rafael Leafar
# 36: Trigger Happy Level by Jeff Mills
# 37: Happy/Sad - 2010 Original Cast Recording from The Addams Family Musical on Broadway by Nathan Lane
# 38: Happy Song - Without Dialogue by Tokyo Disneyland
# 39: Happy Working Song - From "Enchanted" / Soundtrack Version by Amy Adams
# 40: If You're Happy and You Know it Clap Your Hands - Original Mix by Cameron's Bedtime Classics
# 41: If You're Happy and you Know It by Cameron's Bedtime Classics
# 42: Minor Happy by Fred V & Grafix
# 43: Happy Tears by Miles Away;RUNN;AYMEN
# 44: Happy Where We Are by Tritonal;Dylan Matthew;Au5
# 45: Happy Now by Kygo;Sandro Cavazza
# 46: Are you happy? by shy martin
# 47: Happy Now by Zedd;Elley Duhé
# 48: I'm So Happy (with BENEE) by Jeremy Zucker;BENEE
# 49: Happy by Oh Wonder
# 50: Fake Happy by Paramore
# 51: Happy Together by The Turtles
# 52: Happy Xmas (War Is Over) by Lights
# 53: Happy Birthday To Me by The Slingers
# 54: Happy by bdrmm
# 55: Happy People Never Fantasize by Broder Daniel
# 56: Happy House by Siouxsie and the Banshees
# 57: Happy? by Mudvayne
# 58: Last Goodbye - Happy Mix by Charly Lownoise & Mental Theo
# 59: Happy Is Voor Hobo's by Bodylotion
# 60: Shalalie (Original Happyhardcore) by De Mosselman
# 61: Hee Hoo (Happy Høken Rmx) by Boi Foi Toch;Beatcrooks
# 62: Melrose - O - Happy Høken remix by Beatcrooks
# 63: Mooi Wark - Zo geil as een bossie siepels (Beatcrooks Happy Høken RMX) by Beatcrooks
# 64: Happy Hookers (Goes On..) by Dark-E
# 65: One Millionth Happy Customer by The Cassandra Complex
# 66: ARE U HAPPY? by JPEGMAFIA
# 67: Happy Pum Pum by Vybz Kartel
# 68: Happy Home by Blackstreet
# 69: Super Scooter Happy by Kyary Pamyu Pamyu
# 70: Happy Days by Sakurako Ohara
# 71: Happy Strawberry by Yui Ogura
# 72: Happy Holiday by Peggy Lee
# 73: Happy Together by Mel Tormé
# 74: Happy by All Ok
# 75: Gali Mein Chand - Happy by Alka Yagnik
# 76: Surmayee Ankhiyon Mein - Happy Version by Ilaiyaraaja;K. J. Yesudas
# 77: Happy New Year by Vidyasagar;Sunidhi Chauhan;Yogi B
# 78: Happy Birthday/Cumpleaños Feliz by Dora The Explorer
# 79: The Happy Song by Dora The Explorer
# 80: Happy Birthday Slide by Big Mucci
# 81: Happy Birthday Song (Trap Remix) by Pj Panda
# 82: Happy Birthday to You by Boston Soundlabs
# 83: If You're Happy and You Know It (Rúguǒ Nǐ Hěn Gāoxìng Érqiě Nǐ Zhīdào) by Babyboomboom
# 84: Happy & You Know It by Pj Panda
# 85: Elvis Presley Sings Happy Birthday by Rik Gaynor
# 86: Happy Birthday Song (Trap Remix) by Pj Panda;ML3V LLC
# 87: HAPPY U Were Born by Coach Kody;Children's Party;Keelan;Tristan
# 88: If You're Happy and You Know It by Patty Shukla
# 89: Happy Birthday to You by The Nursery Rhymes Superstar
# 90: If You're Happy and You Know It (Si Tu Es Content) by Babyboomboom
# 91: If You're Happy and You Know It by Jack Hartmann
# 92: If You're Happy and You Know It (Si Te Sientes Contento) by Babyboomboom
# 93: Happy Happy by Nacho;Los Mendoza
# 94: I'm Happy by 李凱馨
# 95: Merry Christmas, Happy Holidays by Issues
# 96: Happy Song by Bring Me The Horizon
# 97: Be Happy (feat. Royal & the Serpent) by Sleeping With Sirens;Royal & the Serpent
# 98: Happy Xmas (War Is Over) by Andrea Bocelli;Matteo Bocelli;Virginia Bocelli
# 99: Hope You'll Be Happy by Lim Hyung Joo
# 100: Happy Wife - Happy Life - DJ Selecta Power Remix by Die Draufgänger;DJ Selecta
# 101: Hai Apna Dil To Aawara - Happy by Hemant Kumar;S. D. Burman
# 102: Happy Together by Weezer
# 103: I Hope You're Happy Now by Elvis Costello & The Attractions
# 104: Happy Kids by John De Sohn
# 105: Happy Together - Remastered by The Turtles
# 106: Happy Holidays, You Bastard by blink-182
# 107: Happy Christmas (War Is Over) by John Lennon;Yoko Ono;Wiener Sängerknaben;WienerWunderAllerlei;Gerald Wirth
# 108: Be Happy by 347aidan
# 109: I Know You're Not Happy by Powfu
# 110: happysad by Josh Golden
# 111: Happy Face by Connor Price
# 112: Happy Viche by Grupo Niche
# 113: My Dear Acquaintance (A Happy New Year) by Kristin Chenoweth
# 114: Make Me Happy by Lindsay Mendez;Ben Crawford
# 115: happy to be sad by Ben Platt
# 116: If It Makes You Happy by Sheryl Crow
# 117: Happy Time: Oceanwaves Sounds for Help in Relieving Baby’s Colicky Symptoms by Soothing White Noise for Infant Sleeping and Massage, Crying & Colic Relief
# 118: makeyouhappy by Musiq Soulchild
# 119: Happy to See You by Sarah, the Illstrumentalist
# 120: Happy 35 by Sless Praismo
# 121: Happy Mistakes by Codename Chinadoll;Gradient Island
# 122: Happy New Year by ABBA
# 123: Happy New Year by LOVA
# 124: Happyland by Amanda Jenssen
# 125: Happy New Year by Benny Andersson
# 126: Happy by Rae & Christian;Mark Foster
# 127: Happy Day - Live by Jesus Culture;Kim Walker-Smith
# Enter the number corresponding to your song choice:  119
# You selected: Happy to See You by Sarah, the Illstrumentalist
#
# Recommendations For: 'Happy to See You' by Sarah, the Illstrumentalist:
#
# Using KNN:
# - Tu No Sabes Nada by Jorge Acosta
# - Huldersølv by Byting
# - Montón (U & Me) by GUFI
#
# Using Naive Bayes:
# - Huldersølv by Byting
# - Montón (U & Me) by GUFI
# - Älska Mig by Köttgrottorna
#
# Determining the most closely linked song using Euclidean distance:
#
# The most closely linked song is: 'Huldersølv' by Byting

# %% [markdown]
# # Comparison

# %%
# EEL4930, QMB3302 gave original knowledge for distance metrics and which would be the most effective for this program.
knn_distances = euclidean_distances(data_scaled[list(unique_knn_recs)], userSongFeatures)
nb_distances = euclidean_distances(data_scaled[list(unique_nb_recs)], userSongFeatures)

# %%
plt.figure(figsize=(12, 6))
plt.plot(knn_distances, label='KNN')
plt.plot(nb_distances, label='Naive Bayes')
plt.xticks([0, 1, 2], ['1', '2', '3'])  # Set the tick labels from 1 to 3
plt.title('Euclidean Distance')
plt.xlabel('Song Recommendation')
plt.ylabel('Euclidean Distance')
plt.legend()
plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity

knn_distances2 = cosine_similarity(data_scaled[list(unique_knn_recs)], userSongFeatures)
nb_distances2 = cosine_similarity(data_scaled[list(unique_nb_recs)], userSongFeatures)

# %%
plt.figure(figsize=(12, 6))
plt.plot(knn_distances2, label='KNN')
plt.plot(nb_distances2, label='Naive Bayes')
plt.xticks([0, 1, 2], ['1', '2', '3'])  # Set the tick labels from 1 to 3
plt.title('Cosine Similarity')
plt.xlabel('Song Recommendation')
plt.ylabel('Cosine Similarity')
plt.legend()
plt.show()

# %%
from sklearn.metrics.pairwise import manhattan_distances

knn_distances3 = manhattan_distances(data_scaled[list(unique_knn_recs)], userSongFeatures)
nb_distances3 = manhattan_distances(data_scaled[list(unique_nb_recs)], userSongFeatures)

# %%
plt.figure(figsize=(12, 6))
plt.plot(knn_distances3, label='KNN')
plt.plot(nb_distances3, label='Naive Bayes')
plt.xticks([0, 1, 2], ['1', '2', '3'])  # Set the tick labels from 1 to 3
plt.title('Manhattan Distance')
plt.xlabel('Song Recommendation')
plt.ylabel('Manhattan Distance')
plt.legend()
plt.show()

# %%
from sklearn.metrics.pairwise import pairwise_distances

knn_distances4 = pairwise_distances(data_scaled[list(unique_knn_recs)], userSongFeatures, metric='hamming')
nb_distances4 = pairwise_distances(data_scaled[list(unique_nb_recs)], userSongFeatures, metric='hamming')

# %%
plt.figure(figsize=(12, 6))
plt.plot(knn_distances4, label='KNN')
plt.plot(nb_distances4, label='Naive Bayes')
plt.xticks([0, 1, 2], ['1', '2', '3'])  # Set the tick labels from 1 to 3
plt.title('Hamming Distance')
plt.xlabel('Song Recommendation')
plt.ylabel('Hamming Distance')
plt.legend()
plt.show()

# %%
knn_distances5 = pairwise_distances(data_scaled[list(unique_knn_recs)], userSongFeatures, metric='correlation')
nb_distances5 = pairwise_distances(data_scaled[list(unique_nb_recs)], userSongFeatures, metric='correlation')

# %%
plt.figure(figsize=(12, 6))
plt.plot(knn_distances5, label='KNN')
plt.plot(nb_distances5, label='Naive Bayes')
plt.xticks([0, 1, 2], ['1', '2', '3'])  # Set the tick labels from 1 to 3
plt.title('Correlation Distance')
plt.xlabel('Song Recommendation')
plt.ylabel('Correlation Distance')
plt.legend()
plt.show()
